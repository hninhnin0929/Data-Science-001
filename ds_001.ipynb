# %% [markdown]
# <a href="https://colab.research.google.com/github/hninhnin0929/Data-Science-001/blob/main/ds_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", na_values=['?'])

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/DrTun/datasets/main/trade.csv", na_values=['?'])

df.head(10)
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# 5  2013-02-15  13.93  14.61  13.93  14.50  15628000  AAL
# 6  2013-02-19  14.33  14.56  14.08  14.26  11354400  AAL
# 7  2013-02-20  14.17  14.26  13.15  13.33  14725200  AAL
# 8  2013-02-21  13.62  13.95  12.90  13.37  11922100  AAL
# 9  2013-02-22  13.57  13.60  13.21  13.57   6071400  AAL

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/DrTun/datasets/main/iris.csv", na_values=['?'])

df.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/DrTun/datasets/main/grades.csv", na_values=['?'])

df.head(10)
# Out:
#        Name  StudyHours  Grade
# 0     Allan       10.00   50.0
# 1     Berth       11.50   50.0
# 2   Charles        9.00   47.0
# 3     Rosie       16.00   97.0
# 4     Ethan        9.25   49.0
# 5     Vicky        1.00    3.0
# 6  Frederic       11.50   53.0
# 7    Jimmie        9.00   42.0
# 8    Rhonda        8.50   26.0
# 9  Giovanni       14.50   74.0

# %% [markdown]
# Machine Learning with Titanic Dataset
#
# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# %% [markdown]
# 1) Numpy - Mathematical functions

# %%
import numpy as np
a1 = np.array([10,20,30,40,50,90])
print(type(a1))
print(a1[3])
print(a1.shape)
print(a1.mean())
print(a1.reshape(3,2))
# Out:
# <class 'numpy.ndarray'>
# 40
# (6,)
# 40.0
# [[10 20]
#  [30 40]
#  [50 90]]

# %% [markdown]
# 2) Panda - Dataframe

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/DrTun/datasets/main/titanic.csv", na_values=['?'])

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# 3) Visualization

# %%
import seaborn as sns
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=df)

# %%
import seaborn as seaborn
sns.barplot(x='Age', y='Embarked', hue='Sex', data=df)

# %%
from matplotlib import pyplot as plt
plt.bar(x=df.Sex, height=df.Age)
plt.show()

# %% [markdown]
# 4) Data Clearning

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Cabin'].fillna('N', inplace=True)
y = df['Survived']
x = df.drop('Survived', axis=1)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %% [markdown]
# 5) Scikit-Learn

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# Preprocessing
def fillna(df):
  df['Age'].fillna(df['Age'].mean(), inplace=True)
  df['Cabin'].fillna('N', inplace=True)
  df['Embarked'].fillna('N', inplace=True)
  df['Fare'].fillna(0, inplace=True)
  return df

def drop_features(df):
  df.drop(['Name', 'Ticket', 'PassengerId'], axis=1, inplace=True)
  return df

def format_features(df):
  df['Cabin'] = df['Cabin'].str[:1]
  features = ['Cabin', 'Sex', 'Embarked']
  for feature in features:
    le = preprocessing.LabelEncoder()
    le.fit(df[feature])
    df[feature] = le.transform(df[feature])
  return df

def transform_features(df):
  fillna(df)
  drop_features(df)
  format_features(df)
  return df

labels = df['Survived']
dropped = df.drop('Survived', axis=1)
features = transform_features(dropped)

# %%
# Spliting
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.2, random_state=11)

# %%
# Training
dt_clf = DecisionTreeClassifier(random_state=11)
dt_clf.fit(features_train, labels_train)
# Out:
# DecisionTreeClassifier(random_state=11)

# %%
# Evaluation
prediction = dt_clf.predict(features_test)
print('Decision Tree Accuracy : {0:4f}'.format(accuracy_score(labels_test, prediction)))
# Out:
# Decision Tree Accuracy : 0.787709

# %%
# Predicting
import json
data = """{ "PassengerId" : "1", "Pclass" : "1", "Name" : "Gerald", "Sex" : "female", "Age": "19.0", "SibSp":"1", "Parch":"0", "Ticket":"A/5 21171", "Fare" : "7.25", "Cabin": "NaN", "Embarked": ["S"]}"""
jsdata = json.loads(data)
dataframe = pd.DataFrame.from_dict(jsdata)
dataframe.head(1)
features = transform_features(dataframe)
prediction = dt_clf.predict(dataframe)
prediction[0]
# Out:
# 1
